# %%
import json

# Load the JSON data from a file
with open('Plastic Surgery data.json', 'r') as file:
    data = json.load(file)

# Function to extract domain names from email addresses
def get_domain(email):
    if "@" in email:
        return email.split('@')[1]
    return None

# Extract and print domain names from email addresses
domains = set()  # Use a set to avoid duplicates
for doctor in data:
    email = doctor.get('Email')
    if email:
        domain = get_domain(email)
        if domain:
            domains.add(domain)

# Print the extracted domain names
for domain in domains:
    print(domain)
# Out:
# siluetti.fi
# miamicenterforplasticsurgery.com
# bidmc.harvard.edu
# drsaba.net
# scottsdaleps.com
# centroarenales.com.ar
# wmchealth.org
# klaverklinieken.nl
# takiplasticsurgery.com
# estetica-lm.com.ar
# dpsi.org
# clinicamultipla.com.br
# cirumed.es
# tainaracassol.com.br
# labiaplastycenternyc.com
# uab.edu
# drdower.com
# willandrade.com
# GreenHillsPlasticSurgery.com
# cchmc.org
# plasticsurgeryoahu.com
# gustavopadua.com.br
# cdrmd.com
# polancoplastica.com
# gumucioplasticsurgery.com
# belladerma.com
# uzleuven.be
# globo.com
# RegencySpecialties.com
# drbrucker.com
# jacobsonplasticsurgery.com
# doctorcorey.com
# eharrismd.com
# drbloomplasticsurgery.com
# uci.edu
# 163.com
# sweetgrassplasticsurgery.com
# felipecastroesguerra.com
# carlosvaldivieso.net
# baroneplasticsurgery.com
# surgery.ufl.edu
# fuse.net
# drroyhobbs.com
# towerhealth.org
# orangeplasticsurgeons.com
# liftplastics.com
# egeozgentas.com
# correaplasticsurgery.com
# waldorfcenter.com
# springfieldclinic.com
# drstephengordon.com
# drcanizares.com
# headachesurgery.com
# michelecoopermd.com
# drreidplasticsurgery.ca
# cairnsplasticsurery.com
# eaplasticsurgery.com
# bodybyravi.com
# drfayazi.com
# mah.harvard.edu
# ppsd.com
# enricorobotti.it
# drgoldman.com
# davidteplica.com
# roniluna.com
# med.kindai.ac.jp
# drboll.com
# mymedleads.com
# jasonmartinmd.com
# plasticsurgeryofnj.com
# drbienstock.com
# vvh.org
# sweatplastics.com
# texaspsa.com
# drmarefat.com
# echeagarayplasticsurgery.com
# sih.net
# eberbach.com
# medstar.net
# billingsplasticsurgery.com
# theloudouncenter.com
# mainlineplasticsurgery.com
# roxannejguymd.com
# Austin-Weston.com
# drdeuber.com
# tpsg.net
# drlokeh.com
# drgeppert.com
# mdnps.com
# northwestern.edu
# victoriacosmeticsurgery.com
# drsalibian.com
# carilionclinic.org
# doctorfayman.co.za
# jichi.ac.jp
# nb.aibn.com
# drantonioconde.pt
# unmaskthebeauty.com
# billingformd.com
# yahoo.co.kr
# novackmd.com
# drbernardcarney.com.au
# drfugo.com
# croftsmd.com
# cosmeti.care
# drmeruane.cl
# drhenrys.com
# drjimeneztoribio.com
# drmanishshah.com
# olivieramar.co.uk
# thecentreforcosmeticsurgery.com
# skinvt.com
# vmmc.org
# andresmaldonado.es
# rauplastics.com
# camc.org
# drmarchant.com
# jacksonclinic.com
# CosmeticSurgeryExperts.com
# praxis-drlahoda.ch
# richardkaroo.com
# uthscsa.edu
# ABeauJeu.com
# fineryou.com
# webbplasticsurg.com
# craigbaldenhofermd.com
# natureredefined.com
# blmarkowitzmd.com
# washingtonplastics.com
# drmoraitis.com
# fiorelladonati.it
# dyaplasticsurgery.com
# johnzavellmd.com
# ilovelyleback.com
# drashruf.com
# prssinc.com
# t-online.de
# aspireplasticsurgery.com.au
# drbenvenuti.com
# seed.net.tw
# calobrace.com
# robertfrankmd.com
# andrescamayo.com
# erdemtezel.com
# EastCoastPS.com
# driamjad.com
# PRMAplasticsurgery.com
# millercosmeticsurgery.com
# mail.femh.org.tw
# johnhroffmd.com
# cascadeeyeskin.com
# drearlcampbell.com
# koblenz-aesthetics.com
# mycscenter.com
# dreckhardt.com
# usp.br
# salisburyps.com
# alessandradelclaro.com.br
# seandohertymd.com
# drqplasticsurgery.com
# pureplasticsurgery.com
# DrRafizadeh.com
# pihhealth.org
# mcvh-vcu.edu
# andrewcohenmd.com
# drmazaheri.com
# pscofchicago.com
# gmail.cpm
# hurwitzcenter.com
# pennstatehealth.psu.edu
# comcast.net
# nationalpsurg.com
# surgicalartsonstate.com
# monicafawzy.com
# med.cornell.edu
# DoctorLeonardYu.com
# DrDavidLDavis.com
# montereyplasticsurgery.com
# sandelduggal.com
# asfb.com.au
# DiscoverTheBeauty.com
# klosterstern-praxis.de
# lancasterplasticsurgery.com
# cnplasticsurgery.com
# berksplasticsurgery.com

# %%
len(domains)
# Out:
# 3200

# %%
unique_domains = [domain for domain in domains if domain not in domains_from_file]

print("Domains not in text file but in domain_list:", unique_domains)
# Out:
# Domains not in text file but in domain_list: ['dpraleigh.com', 'aol.com', 'Yahoo.Com', 'nm.org', 'prmaplasticsurgery.com', 'Hotmail.Com', 'OCALAPLASTICSURGERY.COM', 'AOL.COM', 'UNMC.EDU', 'crystalclinic.com', 'austin-weston.com', 'bswhealth.org', 'NorthwesternPlastics.com', 'post.harvard.edu', 'GMAIL.COM', 'nybra.com', 'GMail.com', 'Partners.Org', 'ugent.be', 'TUHS.temple.edu', 'LUMC.EDU', 'UPMC.edu', 'YAHOO.COM', 'Plasticandhand.Com', 'bellsouth.net', 'Gmail.com', 'icloud.com', 'premiumcareps.com', 'Gmail.Com', 'medstar.net', 'Cpsdocs.Com', 'dchstx.org', 'brunobrownplasticsurgery.com', 'msapc.com', 'msn.COM', 'uphs.upenn.edu']

# %%
len(unique_domains)
# Out:
# 36

# %%
import os
import csv

def toCSV(source, rows):
    csv_filename = f'{source}.csv'

    # Determine if the CSV file already exists
    file_exists = os.path.isfile(csv_filename)

    # Write to CSV file
    with open(csv_filename, mode='a' if file_exists else 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerows(rows)

    print(f"Data has been written to {csv_filename}")

# %%
def save_html(source, domain, html_content):
  folder_path = f'./HTML/{source}'
  if not os.path.exists(folder_path):
    os.makedirs(folder_path)

  file_path = folder_path + f'/{domain}.html'
  print(file_path)
  with open(file_path, 'w') as file:
    file.write(html_content)

# %%
from bs4 import BeautifulSoup

def extractData(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    table = soup.find('table')

    if table is None:
        return
    
    # Extract table headers
    headers = [header.text.strip() for header in table.find_all('th')]

    # Extract table rows
    rows = []
    for row in table.find('tbody').find_all('tr'):
        cells = row.find_all('td')
        row_data = [cell.get_text(strip=True) for cell in cells]
        rows.append(row_data)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


import time

domain_list = unique_domains

#initial stuff 
# Set up the WebDriver (this example uses Chrome)
driver = webdriver.Chrome()

# Replace with the URL of the page containing the input field
url = "https://aeroleads.com/email-finder"

driver.get(url)

##clicks button to change to the proper email
button = driver.find_element(By.XPATH, '//*[@id="kt_app_content_container"]/ul/li[2]/a')

# Click the button
button.click()

time.sleep(5)
#? This is what will happen continously 

for domain_name in domain_list:
  # Locate the input field by its ID
  input_field = driver.find_element(By.ID, "domain_input")
  #clear the input before writing to it again
  input_field.clear()
  # Fill in the input field with a value
  input_field.send_keys(domain_name)

  # Optionally, submit the form if necessary (this example presses Enter)
  input_field.send_keys(Keys.RETURN)

  # Close the WebDriver after a short wait to see the result (optional)
  time.sleep(2)

  #now need to get the 
  html_content = driver.page_source
  #save html
  save_html('aeroleads', domain=domain_name, html_content=html_content)
  # data = extractData(html_content=html_content)
  # toCSV('aeroleads', data)
  print(domain_name)
  # with open('finished.txt', 'a') as file:
  #   file.write(domain_name + '\n')

  # time.sleep(1)

driver.quit()
# Out:
# ./HTML/aeroleads/dpraleigh.com.html
# dpraleigh.com
# ./HTML/aeroleads/aol.com.html
# aol.com
# ./HTML/aeroleads/Yahoo.Com.html
# Yahoo.Com
# ./HTML/aeroleads/nm.org.html
# nm.org
# ./HTML/aeroleads/prmaplasticsurgery.com.html
# prmaplasticsurgery.com
# ./HTML/aeroleads/Hotmail.Com.html
# Hotmail.Com
# ./HTML/aeroleads/OCALAPLASTICSURGERY.COM.html
# OCALAPLASTICSURGERY.COM
# ./HTML/aeroleads/AOL.COM.html
# AOL.COM
# ./HTML/aeroleads/UNMC.EDU.html
# UNMC.EDU
# ./HTML/aeroleads/crystalclinic.com.html
# crystalclinic.com
# ./HTML/aeroleads/austin-weston.com.html
# austin-weston.com
# ./HTML/aeroleads/bswhealth.org.html
# bswhealth.org
# ./HTML/aeroleads/NorthwesternPlastics.com.html
# NorthwesternPlastics.com
# ./HTML/aeroleads/post.harvard.edu.html
# post.harvard.edu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 40
#      37 input_field.send_keys(Keys.RETURN)
#      39 # Close the WebDriver after a short wait to see the result (optional)
# ---> 40 time.sleep(2)
#      42 #now need to get the
#      43 html_content = driver.page_source
#
# KeyboardInterrupt:

# %%
#this extracts html and parses the data
directory = '/HTML/aeroleads'  # replace with your directory path
for filename in os.listdir(directory):
    if filename.endswith(".html"):  # only process HTML files
        with open(os.path.join(directory, filename), 'r') as file:
            content = file.read()
            data = extractData(content)
            toCSV('aeroleads', data)
#then the data is saved to csv

# %% [markdown]
# #Structure
#
# Input: List of Domains
# Output: csv of .. FirstName (REQUIRED), LastName, Email(REQUIRED), Company
#
# Files
# - List of Processed Domains (By Site)
# - List of HTML Retrieved Domains (By Site)
#
# 1. Read in List of Domains
# 2. Remove Duplicate Domains * handled via set
# 3. Remove Already Processed Domains
#
# * Piplines are forked because every site has a different search process
# * Need to run one and then the other
#
# 1. Search for Domain on All Sites and Download HTML
# 2. Add domain to list of HTML Retrieved
#
#
# 1. Read in HTML and Retrieve Relevant Data and Save to CSV
# 1. Add domain to processed domains

# %%
import os

def get_finished_HTML_domains(directory='./HTML/aeroleads'):
    # Initialize an empty list to store filenames
    domains_from_file = []

    # Iterate over all files in the directory
    for filename in os.listdir(directory):
        # Check if the file ends with .html
        if filename.endswith('.html'):
            # Remove the .html extension and add to the list
            domains_from_file.append(os.path.splitext(filename)[0])
    
    return domains_from_file

# %%
import json

def get_domains(filename):
  # Load the JSON data from a file
  with open(filename, 'r') as file:
      data = json.load(file)

  # Function to extract domain names from email addresses
  def get_domain(email):
      if "@" in email:
          return email.split('@')[1]
      return None

  # Extract and print domain names from email addresses
  domains = set()  # Use a set to avoid duplicates
  for doctor in data:
      email = doctor.get('Email')
      if email:
          domain = get_domain(email)
          if domain:
              domains.add(domain)

  # Print the extracted domain names
  return domains

# %%
# Function to read domains from a file
def read_domains(file_path):
    with open(file_path, 'r') as file:
        domains = [line.strip() for line in file if line.strip()]
    return domains

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

def download_aero(domains):

  #need to remove the domain if it already has an html file. 
  HTML_domains = get_finished_HTML_domains('./HTML/aeroleads')
  domain_list = dedup(HTML_domains, domains)

  #initial stuff 
  # Set up the WebDriver (this example uses Chrome)
  driver = webdriver.Chrome()

  # Replace with the URL of the page containing the input field
  url = "https://aeroleads.com/email-finder"

  driver.get(url)

  ##clicks button to change to the proper email
  button = driver.find_element(By.XPATH, '//*[@id="kt_app_content_container"]/ul/li[2]/a')

  # Click the button
  button.click()

  time.sleep(5)

  for domain_name in domain_list:
    # Locate the input field by its ID
    input_field = driver.find_element(By.ID, "domain_input")
    #clear the input before writing to it again
    input_field.clear()
    # Fill in the input field with a value
    input_field.send_keys(domain_name)

    # Optionally, submit the form if necessary (this example presses Enter)
    input_field.send_keys(Keys.RETURN)

    # Close the WebDriver after a short wait to see the result (optional)
    time.sleep(2)

    #now need to get the 
    html_content = driver.page_source
    #save html
    save_html('aeroleads', domain=domain_name, html_content=html_content)

  driver.quit()

# %%
def extract_aero(html_directory, finished_file):
    """
    Extracts domains from HTML files in a directory and processes only those not in the finished file.

    Args:
    html_directory (str): The directory containing HTML files.
    finished_file (str): Path to the file containing already processed domains.

    Returns:
    list: List of domains that have been processed.
    """
    # Read finished domains from the file
    with open(finished_file, 'r') as file:
        finished_domains = set(line.strip() for line in file)

    for filename in os.listdir(html_directory):
        if filename.endswith('.html'):
            # Extract domain from filename (removing the .html extension)
            domain = filename[:-5]
            
            # Process only if domain is not in finished list
            if domain not in finished_domains:
                # Open and read the HTML file
                with open(os.path.join(html_directory, filename), 'r') as file:
                    content = file.read()
                    
                    # Extract data from the content
                    data = extractData(content)
                    
                    # Write the data to a CSV file
                    toCSV('aeroleads', data)
                    
                    # Add domain to processed domains
                    with open('finished.txt', 'a') as file:
                      file.write(domain_name + '\n')

# %%
def process_domains(filepath):
  domains = get_domains(filename=filepath)
  download_aero(domains)
  extract_aero('./HTML/aeroleads', './finished.txt')
